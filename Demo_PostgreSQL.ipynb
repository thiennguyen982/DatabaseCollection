# %%
from psycopg2 import connect

# %%
conn = connect(
    host='localhost',
    database='qlbanhang',
    user='postgres',
    password='123456',
    port='5432'
)

# %%
cursor = conn.cursor()
sql = '''SELECT * FROM product WHERE "ProductName" LIKE 'Ch%' '''
cursor.execute(sql)
print(cursor.fetchall())
cursor.close()
# Out:
# [(1, 'Chai', 1, 18.0, '10 boxes x 20 bags', '0'), (2, 'Chang', 1, 19.0, '24 - 12 oz bottles', '0'), (4, "Chef Anton's Ca6/Seasoning", 2, 22.0, '48 - 6 oz jars', '0'), (5, "Chef Anton's Gumbo Mix", 2, 21.35, '36 boxes', '1'), (39, 'Chartreuse verte', 18, 18.0, '750 cc per bottle', '0'), (48, 'Chocolade', 22, 12.75, '10 pkgs.', '0')]

# %% [markdown]
# Magic SQL

# %%
# %load_ext sql

# %%
# %sql postgresql://postgres:123456@localhost/qlbanhang

# %%
# %sql SELECT * FROM product LIMIT 22
# Out:
#  * postgresql://postgres:***@localhost/qlbanhang
# 22 rows affected.
# [(1, 'Chai', 1, 18.0, '10 boxes x 20 bags', '0'),
#  (2, 'Chang', 1, 19.0, '24 - 12 oz bottles', '0'),
#  (3, 'Aniseed Syrup', 1, 10.0, '12 - 550 ml bottles', '0'),
#  (4, "Chef Anton's Ca6/Seasoning", 2, 22.0, '48 - 6 oz jars', '0'),
#  (5, "Chef Anton's Gumbo Mix", 2, 21.35, '36 boxes', '1'),
#  (6, "Grandma's Boysenberry Spread", 3, 25.0, '12 - 8 oz jars', '0'),
#  (7, "Uncle Bob's Organic Dried Pears", 3, 30.0, '12 - 1 lb pkgs.', '0'),
#  (8, 'Northwoods Cranberry Sauce', 3, 40.0, '12 - 12 oz jars', '0'),
#  (9, 'Mishi Kobe Niku', 4, 97.0, '18 - 500 g pkgs.', '1'),
#  (10, 'Ikura', 4, 31.0, '12 - 200 ml jars', '0'),
#  (11, 'Queso Cabrales', 5, 21.0, '1 kg pkg.', '0'),
#  (12, 'Queso Manchego La Pastora', 5, 38.0, '10 - 500 g pkgs.', '0'),
#  (13, 'Konbu', 6, 6.0, '2 kg box', '0'),
#  (14, 'Tofu', 6, 23.25, '40 - 100 g pkgs.', '0'),
#  (15, 'Genen Shouyu', 6, 15.5, '24 - 250 ml bottles', '0'),
# ...
